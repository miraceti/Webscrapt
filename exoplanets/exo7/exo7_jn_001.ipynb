# %%
from urllib.request import urlopen
import json
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_18100/4045076115.py in <module>
#       1 from urllib.request import urlopen
#       2 import json
# ----> 3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
urlexo1 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json"
print(urlexo1)
data = json.loads(urlopen(urlexo1).read().decode("utf-8"))
# print(data)
data0=data[0]
# print(data0)
nb_exoplanets= data0['nbe']
print(nb_exoplanets)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json
# 5678

# %%
print(data0)
# Out:
# {'nbe': 5678}

# %%
urlexo7_001a= "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name+from+ps+where+default_flag=1&format=json"
print(urlexo7_001a)
data_001a = json.loads(urlopen(urlexo7_001a).read().decode("utf-8"))
print(data_001a)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name+from+ps+where+default_flag=1&format=json
# ...

# %%
print(len(data_001a))
# Out:
# 5678

# %%
data_001a.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18100/1724902160.py in <module>
# ----> 1 data_001a.shape()
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
df = pd.DataFrame(data_001a)
