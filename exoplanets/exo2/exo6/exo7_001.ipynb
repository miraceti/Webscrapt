# %%
import pandas as pd
import flet as ft
from urllib.request import urlopen
import json

# %%
urlexo1 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json"
print(urlexo1)
data = json.loads(urlopen(urlexo1).read().decode("utf-8"))
# print(data)
data0=data[0]
# print(data0)
nb_exoplanets= data0['nbe']
print(nb_exoplanets)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json
# 5678

# %%
urlexo7 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod\
+from+ps+where+default_flag=1&format=json"

print(urlexo7)
list7 = json.loads(urlopen(urlexo7).read().decode("utf-8"))
print(list7)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod+from+ps+where+default_flag=1&format=json
# [{'pl_name': 'OGLE-TR-10 b', 'hostname': 'OGLE-TR-10', 'pl_letter': 'b', 'pl_bmasse': 197.046, 'pl_bmassj': 0.62, 'pl_rade': 14.011, 'pl_radj': 1.25, 'pl_orbper': 3.101278, 'pl_dens': 0.4, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 1.14, 'st_lum': 0.188, 'st_age': None, 'st_dens': None, 'sy_dist': 1344.97, 'disc_year': 2004, 'disc_telescope': '1.3 m Warsaw University Telescope', 'discoverymethod': 'Transit'}, {'pl_name': 'BD-08 2823 c', 'hostname': 'BD-08 2823', 'pl_letter': 'c', 'pl_bmasse': 104.0, 'pl_bmassj': 0.33, 'pl_rade': None, 'pl_radj': None, 'pl_orbper': 237.6, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 2, 'sy_mnum': 0, 'st_mass': 0.74, 'st_lum': None, 'st_age': 4.5, 'st_dens': None, 'sy_dist': 41.3342, 'disc_year': 2009, 'disc_telescope': '3.6 m ESO Telescope', 'discoverymethod': 'Radial Velocity'}, {'pl_name': 'HR 8799 c', 'hostname': 'HR 8799', 'pl_letter': 'c', 'pl_bmasse': 3000.0, 'pl_bmassj': 10.0, 'pl_rade': 13.0, 'pl_radj': 1.2, 'pl_orbper': 69000.0, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 1.5, 'st_lum': 0.692, 'st_age': 0.06, 'st_dens': None, 'sy_dist': 41.2441, 'disc_year': 2008, 'disc_telescope': '8.19 m Gemini North Telescope', 'discoverymethod': 'Imaging'}, {'pl_name': 'HD 110014 b', 'hostname': 'HD 110014', 'pl_letter': 'b', 'pl_bmasse': 3524.59, 'pl_bmassj': 11.09, 'pl_rade': None, 'pl_radj': None, 'pl_orbper': 835.477, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 2.17, 'st_lum': None, 'st_age': 0.95, 'st_dens': None, 'sy_dist': 100.758, 'disc_year': 2009, 'disc_telescope': 'Multiple Telescopes', 'discoverymethod': 'Radial Velocity'}, {'pl_name': 'WASP-43 b', 'hostname': 'WASP-43', 'pl_letter': 'b', 'pl_bmasse': 565.714, 'pl_bmassj': 1.78, 'pl_rade': 10.424, 'pl_radj': 0.93, 'pl_orbper': 0.813475, 'pl_dens': 2.939, 'pl_trandur': 1.1592, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 0.58, 'st_lum': None, 'st_age': None, 'st_dens': None, 'sy_dist': 86.7467, 'disc_year': 2011, 'disc_telescope': 'Canon 200mm f/1.8L', 'discoverymethod': 'Transit'}, {'pl_name': 'WASP-47 b', 'hostname': 'WASP-47', 'pl_letter': 'b', 'pl_bmasse': 374.0, 'pl_bmassj': 1.17674, 'pl_rade': 12.86, 'pl_radj': 1.147, 'pl_orbper': 4.159151, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 1.06, 'st_lum': None, 'st_age': None, 'st_dens': None, 'sy_dist': 264.78, 'disc_year': 2012, 'disc_telescope': 'Canon 200mm f/1.8L', 'discoverymethod': 'Transit'}, {'pl_name': 'WASP-47 c', 'hostname': 'WASP-47', 'pl_letter': 'c', 'pl_bmasse': 447.0, 'pl_bmassj': 1.40642, 'pl_rade': None, 'pl_radj': None, 'pl_orbper': 589.57, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 1.06, 'st_lum': None, 'st_age': None, 'st_dens': None, 'sy_dist': 264.78, 'disc_year': 2015, 'disc_telescope': '1.2 m Leonhard Euler Telescope', 'discoverymethod': 'Radial Velocity'}, {'pl_name': 'WASP-47 d', 'hostname': 'WASP-47', 'pl_letter': 'd', 'pl_bmasse': 15.5, 'pl_bmassj': 0.04877, 'pl_rade': 3.65, 'pl_radj': 0.326, 'pl_orbper': 9.030501, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 1.06, 'st_lum': None, 'st_age': None, 'st_dens': None, 'sy_dist': 264.78, 'disc_year': 2015, 'disc_telescope': '0.95 m Kepler Telescope', 'discoverymethod': 'Transit'}, {'pl_name': 'WASP-47 e', 'hostname': 'WASP-47', 'pl_letter': 'e', 'pl_bmasse': 9.0, 'pl_bmassj': 0.02832, 'pl_rade': 1.83, 'pl_radj': 0.163, 'pl_orbper': 0.78961, 'pl_dens': None, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 1.06, 'st_lum': None, 'st_age': None, 'st_dens': None, 'sy_dist': 264.78, 'disc_year': 2015, 'disc_telescope': '0.95 m Kepler Telescope', 'd ...

# %%
list7
# Out:
# [{'pl_name': 'OGLE-TR-10 b',
#   'hostname': 'OGLE-TR-10',
#   'pl_letter': 'b',
#   'pl_bmasse': 197.046,
#   'pl_bmassj': 0.62,
#   'pl_rade': 14.011,
#   'pl_radj': 1.25,
#   'pl_orbper': 3.101278,
#   'pl_dens': 0.4,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.14,
#   'st_lum': 0.188,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1344.97,
#   'disc_year': 2004,
#   'disc_telescope': '1.3 m Warsaw University Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'BD-08 2823 c',
#   'hostname': 'BD-08 2823',
#   'pl_letter': 'c',
#   'pl_bmasse': 104.0,
#   'pl_bmassj': 0.33,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 237.6,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.74,
#   'st_lum': None,
#   'st_age': 4.5,
#   'st_dens': None,
#   'sy_dist': 41.3342,
#   'disc_year': 2009,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'HR 8799 c',
#   'hostname': 'HR 8799',
#   'pl_letter': 'c',
#   'pl_bmasse': 3000.0,
#   'pl_bmassj': 10.0,
#   'pl_rade': 13.0,
#   'pl_radj': 1.2,
#   'pl_orbper': 69000.0,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 1.5,
#   'st_lum': 0.692,
#   'st_age': 0.06,
#   'st_dens': None,
#   'sy_dist': 41.2441,
#   'disc_year': 2008,
#   'disc_telescope': '8.19 m Gemini North Telescope',
#   'discoverymethod': 'Imaging'},
#  {'pl_name': 'HD 110014 b',
#   'hostname': 'HD 110014',
#   'pl_letter': 'b',
#   'pl_bmasse': 3524.59,
#   'pl_bmassj': 11.09,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 835.477,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.17,
#   'st_lum': None,
#   'st_age': 0.95,
#   'st_dens': None,
#   'sy_dist': 100.758,
#   'disc_year': 2009,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'WASP-43 b',
#   'hostname': 'WASP-43',
#   'pl_letter': 'b',
#   'pl_bmasse': 565.714,
#   'pl_bmassj': 1.78,
#   'pl_rade': 10.424,
#   'pl_radj': 0.93,
#   'pl_orbper': 0.813475,
#   'pl_dens': 2.939,
#   'pl_trandur': 1.1592,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.58,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 86.7467,
#   'disc_year': 2011,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-47 b',
#   'hostname': 'WASP-47',
#   'pl_letter': 'b',
#   'pl_bmasse': 374.0,
#   'pl_bmassj': 1.17674,
#   'pl_rade': 12.86,
#   'pl_radj': 1.147,
#   'pl_orbper': 4.159151,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 264.78,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-47 c',
#   'hostname': 'WASP-47',
#   'pl_letter': 'c',
#   'pl_bmasse': 447.0,
#   'pl_bmassj': 1.40642,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 589.57,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 264.78,
#   'disc_year': 2015,
#   'disc_telescope': '1.2 m Leonhard Euler Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'WASP-47 d',
#   'hostname': 'WASP-47',
#   'pl_letter': 'd',
#   'pl_bmasse': 15.5,
#   'pl_bmassj': 0.04877,
#   'pl_rade': 3.65,
#   'pl_radj': 0.326,
#   'pl_orbper': 9.030501,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 264.78,
#   'disc_year': 2015,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-47 e',
#   'hostname': 'WASP-47',
#   'pl_letter': 'e',
#   'pl_bmasse': 9.0,
#   'pl_bmassj': 0.02832,
#   'pl_rade': 1.83,
#   'pl_radj': 0.163,
#   'pl_orbper': 0.78961,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 264.78,
#   'disc_year': 2015,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5704 b',
#   'hostname': 'TOI-5704',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.227,
#   'pl_radj': 0.288,
#   'pl_orbper': 3.771116,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0389,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.73,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 89.637,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 23472 d',
#   'hostname': 'HD 23472',
#   'pl_letter': 'd',
#   'pl_bmasse': 0.55,
#   'pl_bmassj': 0.00173,
#   'pl_rade': 0.75,
#   'pl_radj': 0.067,
#   'pl_orbper': 3.97664,
#   'pl_dens': 7.5,
#   'pl_trandur': 1.99,
#   'pl_ratror': 0.00975,
#   'sy_snum': 1,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.67,
#   'st_lum': -0.625,
#   'st_age': None,
#   'st_dens': 2.7069,
#   'sy_dist': 39.0341,
#   'disc_year': 2022,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2194 b',
#   'hostname': 'TOI-2194',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.989,
#   'pl_radj': 0.177,
#   'pl_orbper': 15.337597,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0263,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.74,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 19.5711,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-672 b',
#   'hostname': 'TOI-672',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 5.26,
#   'pl_radj': 0.469,
#   'pl_orbper': 3.633575,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0885,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.54,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 66.9071,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-199 b',
#   'hostname': 'TOI-199',
#   'pl_letter': 'b',
#   'pl_bmasse': 54.03083,
#   'pl_bmassj': 0.17,
#   'pl_rade': 9.079,
#   'pl_radj': 0.81,
#   'pl_orbper': 104.854,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.94,
#   'st_lum': -0.338,
#   'st_age': 0.8,
#   'st_dens': 2.39,
#   'sy_dist': 102.27,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-199 c',
#   'hostname': 'TOI-199',
#   'pl_letter': 'c',
#   'pl_bmasse': 88.99195,
#   'pl_bmassj': 0.28,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 273.69,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.94,
#   'st_lum': -0.338,
#   'st_age': 0.8,
#   'st_dens': 2.39,
#   'sy_dist': 102.27,
#   'disc_year': 2023,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Transit Timing Variations'},
#  {'pl_name': 'KELT-18 b',
#   'hostname': 'KELT-18',
#   'pl_letter': 'b',
#   'pl_bmasse': 375.0394,
#   'pl_bmassj': 1.18,
#   'pl_rade': 17.598,
#   'pl_radj': 1.57,
#   'pl_orbper': 2.8717518,
#   'pl_dens': 0.377,
#   'pl_trandur': 4.644,
#   'pl_ratror': 0.08462,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.52,
#   'st_lum': 0.813,
#   'st_age': 1.9,
#   'st_dens': 0.3111,
#   'sy_dist': 321.376,
#   'disc_year': 2017,
#   'disc_telescope': 'Mamiya 645 80mm f/1.9',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2096 c',
#   'hostname': 'TOI-2096',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.914,
#   'pl_radj': 0.171,
#   'pl_orbper': 6.38784,
#   'pl_dens': None,
#   'pl_trandur': 1.354,
#   'pl_ratror': 0.0747,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.23,
#   'st_lum': -2.228,
#   'st_age': 4.0,
#   'st_dens': 23.9,
#   'sy_dist': 48.4809,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HIP 5158 b',
#   'hostname': 'HIP 5158',
#   'pl_letter': 'b',
#   'pl_bmasse': 451.0,
#   'pl_bmassj': 1.42,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 345.72,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.78,
#   'st_lum': -0.959,
#   'st_age': 6.0,
#   'st_dens': None,
#   'sy_dist': 51.6026,
#   'disc_year': 2009,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'HD 132563 b',
#   'hostname': 'HD 132563',
#   'pl_letter': 'b',
#   'pl_bmasse': 473.547,
#   'pl_bmassj': 1.49,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 1544.0,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.23,
#   'st_lum': 0.374,
#   'st_age': None,
#   'st_dens': 0.7977,
#   'sy_dist': 105.155,
#   'disc_year': 2011,
#   'disc_telescope': '3.58 m Telescopio Nazionale Galileo',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'GJ 667 C b',
#   'hostname': 'GJ 667 C',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 7.203,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 7.24396,
#   'disc_year': 2012,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'GJ 667 C c',
#   'hostname': 'GJ 667 C',
#   'pl_letter': 'c',
#   'pl_bmasse': 3.8,
#   'pl_bmassj': 0.012,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 28.14,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.33,
#   'st_lum': -1.863,
#   'st_age': 2.0,
#   'st_dens': None,
#   'sy_dist': 7.24396,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'GJ 667 C e',
#   'hostname': 'GJ 667 C',
#   'pl_letter': 'e',
#   'pl_bmasse': 2.7,
#   'pl_bmassj': 0.008,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 62.24,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.33,
#   'st_lum': -1.863,
#   'st_age': 2.0,
#   'st_dens': None,
#   'sy_dist': 7.24396,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'GJ 667 C f',
#   'hostname': 'GJ 667 C',
#   'pl_letter': 'f',
#   'pl_bmasse': 2.7,
#   'pl_bmassj': 0.008,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 39.026,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.33,
#   'st_lum': -1.863,
#   'st_age': 2.0,
#   'st_dens': None,
#   'sy_dist': 7.24396,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'GJ 667 C g',
#   'hostname': 'GJ 667 C',
#   'pl_letter': 'g',
#   'pl_bmasse': 4.6,
#   'pl_bmassj': 0.014,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 256.2,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.33,
#   'st_lum': -1.863,
#   'st_age': 2.0,
#   'st_dens': None,
#   'sy_dist': 7.24396,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'CHXR 73 b',
#   'hostname': 'CHXR 73',
#   'pl_letter': 'b',
#   'pl_bmasse': 3994.486,
#   'pl_bmassj': 12.569,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': None,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.35,
#   'st_lum': None,
#   'st_age': 0.002,
#   'st_dens': None,
#   'sy_dist': 190.374,
#   'disc_year': 2006,
#   'disc_telescope': '2.4 m Hubble Space Telescope',
#   'discoverymethod': 'Imaging'},
#  {'pl_name': 'alf Ari b',
#   'hostname': 'alf Ari',
#   'pl_letter': 'b',
#   'pl_bmasse': 572.07,
#   'pl_bmassj': 1.8,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 380.8,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.5,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 20.21019,
#   'disc_year': 2010,
#   'disc_telescope': '1.8 m Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'Kepler-370 c',
#   'hostname': 'Kepler-370',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.91,
#   'pl_radj': 0.17,
#   'pl_orbper': 19.02293,
#   'pl_dens': None,
#   'pl_trandur': 3.418,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1167.94,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-400 b',
#   'hostname': 'Kepler-400',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.65,
#   'pl_radj': 0.147,
#   'pl_orbper': 9.024389,
#   'pl_dens': None,
#   'pl_trandur': 3.128,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 845.97,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-221 b',
#   'hostname': 'Kepler-221',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.71,
#   'pl_radj': 0.153,
#   'pl_orbper': 2.795906,
#   'pl_dens': None,
#   'pl_trandur': 2.064,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 385.231,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-367 c',
#   'hostname': 'Kepler-367',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.2,
#   'pl_radj': 0.107,
#   'pl_orbper': 53.578637,
#   'pl_dens': None,
#   'pl_trandur': 5.236,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 188.027,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-393 c',
#   'hostname': 'Kepler-393',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.33,
#   'pl_radj': 0.119,
#   'pl_orbper': 14.613612,
#   'pl_dens': None,
#   'pl_trandur': 5.401,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 881.404,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-304 c',
#   'hostname': 'Kepler-304',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.17,
#   'pl_radj': 0.194,
#   'pl_orbper': 5.315946,
#   'pl_dens': None,
#   'pl_trandur': 1.114,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 434.684,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-360 b',
#   'hostname': 'Kepler-360',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.65,
#   'pl_radj': 0.147,
#   'pl_orbper': 3.289672,
#   'pl_dens': None,
#   'pl_trandur': 2.312,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 876.044,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-243 c',
#   'hostname': 'Kepler-243',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.99,
#   'pl_radj': 0.178,
#   'pl_orbper': 20.026218,
#   'pl_dens': None,
#   'pl_trandur': 1.319,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 693.86,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-261 c',
#   'hostname': 'Kepler-261',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.0,
#   'pl_radj': 0.178,
#   'pl_orbper': 24.570858,
#   'pl_dens': None,
#   'pl_trandur': 2.761,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 317.499,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-327 d',
#   'hostname': 'Kepler-327',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.73,
#   'pl_radj': 0.154,
#   'pl_orbper': 13.969457,
#   'pl_dens': None,
#   'pl_trandur': 1.408,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 241.987,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-136 b',
#   'hostname': 'Kepler-136',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.05,
#   'pl_radj': 0.183,
#   'pl_orbper': 11.5789,
#   'pl_dens': None,
#   'pl_trandur': 2.855,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 420.818,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-122 d',
#   'hostname': 'Kepler-122',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.2,
#   'pl_radj': 0.196,
#   'pl_orbper': 21.587475,
#   'pl_dens': None,
#   'pl_trandur': 4.683,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1027.45,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-157 c',
#   'hostname': 'Kepler-157',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.24,
#   'pl_radj': 0.2,
#   'pl_orbper': 13.5405,
#   'pl_dens': None,
#   'pl_trandur': 4.514,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 773.713,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-147 c',
#   'hostname': 'Kepler-147',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.43,
#   'pl_radj': 0.217,
#   'pl_orbper': 33.416423,
#   'pl_dens': None,
#   'pl_trandur': 7.293,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1042.02,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-239 b',
#   'hostname': 'Kepler-239',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.33,
#   'pl_radj': 0.208,
#   'pl_orbper': 11.763051,
#   'pl_dens': None,
#   'pl_trandur': 2.899,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 648.109,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-200 b',
#   'hostname': 'Kepler-200',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.13,
#   'pl_radj': 0.19,
#   'pl_orbper': 8.594805,
#   'pl_dens': None,
#   'pl_trandur': 3.534,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 665.912,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-243 b',
#   'hostname': 'Kepler-243',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.45,
#   'pl_radj': 0.219,
#   'pl_orbper': 5.715442,
#   'pl_dens': None,
#   'pl_trandur': 2.484,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 693.86,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-254 b',
#   'hostname': 'Kepler-254',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.87,
#   'pl_radj': 0.345,
#   'pl_orbper': 5.826662,
#   'pl_dens': None,
#   'pl_trandur': 3.032,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1389.48,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-172 c',
#   'hostname': 'Kepler-172',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.86,
#   'pl_radj': 0.255,
#   'pl_orbper': 6.388996,
#   'pl_dens': None,
#   'pl_trandur': 3.389,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 828.592,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-299 c',
#   'hostname': 'Kepler-299',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.65,
#   'pl_radj': 0.236,
#   'pl_orbper': 6.885875,
#   'pl_dens': None,
#   'pl_trandur': 4.009,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1052.24,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-278 c',
#   'hostname': 'Kepler-278',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.59,
#   'pl_radj': 0.32,
#   'pl_orbper': 51.078775,
#   'pl_dens': None,
#   'pl_trandur': 11.315,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 443.03,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-339 d',
#   'hostname': 'Kepler-339',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.17,
#   'pl_radj': 0.104,
#   'pl_orbper': 10.558345,
#   'pl_dens': None,
#   'pl_trandur': 3.41,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 616.637,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-397 b',
#   'hostname': 'Kepler-397',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.46,
#   'pl_radj': 0.219,
#   'pl_orbper': 22.250949,
#   'pl_dens': None,
#   'pl_trandur': 1.689,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': None,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'Kepler-399 b',
#   'hostname': 'Kepler-399',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 0.96,
#   'pl_radj': 0.086,
#   'pl_orbper': 14.425281,
#   'pl_dens': None,
#   'pl_trandur': 3.686,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 740.537,
#   'disc_year': 2014,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 219415 b',
#   'hostname': 'HD 219415',
#   'pl_letter': 'b',
#   'pl_bmasse': 317.83,
#   'pl_bmassj': 1.0,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 2093.3,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.0,
#   'st_lum': 0.62,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 165.184,
#   'disc_year': 2012,
#   'disc_telescope': '9.2 m Hobby-Eberly Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'HD 207832 c',
#   'hostname': 'HD 207832',
#   'pl_letter': 'c',
#   'pl_bmasse': 232.0159,
#   'pl_bmassj': 0.73,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 1155.7,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 3,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.94,
#   'st_lum': -0.112,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 58.9291,
#   'disc_year': 2012,
#   'disc_telescope': '10 m Keck I Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'WASP-176 b',
#   'hostname': 'WASP-176',
#   'pl_letter': 'b',
#   'pl_bmasse': 271.74465,
#   'pl_bmassj': 0.855,
#   'pl_rade': 16.87,
#   'pl_radj': 1.505,
#   'pl_orbper': 3.899052,
#   'pl_dens': 0.31,
#   'pl_trandur': 5.1528,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.34,
#   'st_lum': None,
#   'st_age': 4.81,
#   'st_dens': 0.371,
#   'sy_dist': 568.42,
#   'disc_year': 2020,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-1801 b',
#   'hostname': 'TOI-1801',
#   'pl_letter': 'b',
#   'pl_bmasse': 5.738,
#   'pl_bmassj': 0.01805,
#   'pl_rade': 2.079,
#   'pl_radj': 0.186,
#   'pl_orbper': 10.64387,
#   'pl_dens': 3.701,
#   'pl_trandur': None,
#   'pl_ratror': 0.034,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.56,
#   'st_lum': -1.23,
#   'st_age': 0.7,
#   'st_dens': None,
#   'sy_dist': 30.6796,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'ITG 15 b',
#   'hostname': 'ITG 15 A',
#   'pl_letter': 'b',
#   'pl_bmasse': 6674.39655,
#   'pl_bmassj': 21.0,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': None,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': None,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 136.37,
#   'disc_year': 2024,
#   'disc_telescope': '1.45 m x 0.5 m Telescope',
#   'discoverymethod': 'Imaging'},
#  {'pl_name': 'K2-178 b',
#   'hostname': 'K2-178',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.558,
#   'pl_radj': 0.317,
#   'pl_orbper': 8.747818,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.03676,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.95,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 214.753,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-4 b',
#   'hostname': 'WASP-4',
#   'pl_letter': 'b',
#   'pl_bmasse': 376.94638,
#   'pl_bmassj': 1.186,
#   'pl_rade': 14.807,
#   'pl_radj': 1.321,
#   'pl_orbper': 1.33823147,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.15201,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.86,
#   'st_lum': None,
#   'st_age': 7.0,
#   'st_dens': 1.711,
#   'sy_dist': 267.206,
#   'disc_year': 2007,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-1693 b',
#   'hostname': 'TOI-1693',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.41,
#   'pl_radj': 0.126,
#   'pl_orbper': 1.7666957,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.49,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 30.7947,
#   'disc_year': 2022,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-399 b',
#   'hostname': 'K2-399',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 6.049,
#   'pl_radj': 0.54,
#   'pl_orbper': 0.759978,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0359,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.78,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 515.491,
#   'disc_year': 2022,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-98 b',
#   'hostname': 'K2-98',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 5.2,
#   'pl_radj': 0.464,
#   'pl_orbper': 10.136448,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0304,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.2,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 0.633,
#   'sy_dist': 518.625,
#   'disc_year': 2016,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-271 b',
#   'hostname': 'K2-271',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 7.28,
#   'pl_radj': 0.649,
#   'pl_orbper': 8.562421,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0674,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.83,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 2.284,
#   'sy_dist': 564.454,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-133 e',
#   'hostname': 'K2-133',
#   'pl_letter': 'e',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.73,
#   'pl_radj': 0.154,
#   'pl_orbper': 26.5841,
#   'pl_dens': None,
#   'pl_trandur': 1.44,
#   'pl_ratror': 0.0348,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 0.46,
#   'st_lum': -1.479,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 75.1703,
#   'disc_year': 2019,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-133 d',
#   'hostname': 'K2-133',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.003,
#   'pl_radj': 0.179,
#   'pl_orbper': 11.02454,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0404,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 0.46,
#   'st_lum': -1.479,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 75.1703,
#   'disc_year': 2017,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-330 b',
#   'hostname': 'K2-330',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.77,
#   'pl_radj': 0.247,
#   'pl_orbper': 13.774798,
#   'pl_dens': None,
#   'pl_trandur': 4.57,
#   'pl_ratror': 0.0169,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.23,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 160.125,
#   'disc_year': 2016,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-105 b',
#   'hostname': 'K2-105',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.59,
#   'pl_radj': 0.32,
#   'pl_orbper': 8.2669928,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0339,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.05,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 197.989,
#   'disc_year': 2017,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-3807 b',
#   'hostname': 'TOI-3807',
#   'pl_letter': 'b',
#   'pl_bmasse': 330.54154,
#   'pl_bmassj': 1.04,
#   'pl_rade': 18.495,
#   'pl_radj': 1.65,
#   'pl_orbper': 2.8989727,
#   'pl_dens': 0.289,
#   'pl_trandur': 1.78,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.18,
#   'st_lum': 0.332,
#   'st_age': 5.6,
#   'st_dens': 0.521,
#   'sy_dist': 421.745,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-148 b',
#   'hostname': 'K2-148',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.33,
#   'pl_radj': 0.119,
#   'pl_orbper': 4.38395,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0193,
#   'sy_snum': 2,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.65,
#   'st_lum': -0.996,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 124.458,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-4087 b',
#   'hostname': 'TOI-4087',
#   'pl_letter': 'b',
#   'pl_bmasse': 232.01474,
#   'pl_bmassj': 0.73,
#   'pl_rade': 13.047,
#   'pl_radj': 1.164,
#   'pl_orbper': 3.1774835,
#   'pl_dens': 0.57,
#   'pl_trandur': 2.9842,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.18,
#   'st_lum': 0.176,
#   'st_age': 0.8,
#   'st_dens': 1.205,
#   'sy_dist': 301.676,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2818 b',
#   'hostname': 'TOI-2818',
#   'pl_letter': 'b',
#   'pl_bmasse': 225.65817,
#   'pl_bmassj': 0.71,
#   'pl_rade': 15.278,
#   'pl_radj': 1.363,
#   'pl_orbper': 4.039709,
#   'pl_dens': 0.34,
#   'pl_trandur': 3.804,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.98,
#   'st_lum': 0.164,
#   'st_age': 9.5,
#   'st_dens': 0.745,
#   'sy_dist': 312.674,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2096 b',
#   'hostname': 'TOI-2096',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.243,
#   'pl_radj': 0.111,
#   'pl_orbper': 3.1190633,
#   'pl_dens': None,
#   'pl_trandur': 1.072,
#   'pl_ratror': 0.0485,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.23,
#   'st_lum': -2.228,
#   'st_age': 4.0,
#   'st_dens': 23.9,
#   'sy_dist': 48.4809,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-3235 b',
#   'hostname': 'TOI-3235',
#   'pl_letter': 'b',
#   'pl_bmasse': 211.35589,
#   'pl_bmassj': 0.665,
#   'pl_rade': 11.4,
#   'pl_radj': 1.017,
#   'pl_orbper': 2.59261842,
#   'pl_dens': 0.78,
#   'pl_trandur': 1.48,
#   'pl_ratror': 0.2828,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.39,
#   'st_lum': -1.79,
#   'st_age': None,
#   'st_dens': 10.99,
#   'sy_dist': 72.811,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-4463 A b',
#   'hostname': 'TOI-4463 A',
#   'pl_letter': 'b',
#   'pl_bmasse': 252.35576,
#   'pl_bmassj': 0.794,
#   'pl_rade': 13.26,
#   'pl_radj': 1.183,
#   'pl_orbper': 2.8807198,
#   'pl_dens': 0.595,
#   'pl_trandur': 1.85,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': 0.011,
#   'st_age': 4.1,
#   'st_dens': 1.24,
#   'sy_dist': 173.117,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 213885 c',
#   'hostname': 'HD 213885',
#   'pl_letter': 'c',
#   'pl_bmasse': 19.95,
#   'pl_bmassj': 0.06277,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 4.78503,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 1.07,
#   'st_lum': 0.139,
#   'st_age': 3.8,
#   'st_dens': 1.127,
#   'sy_dist': 48.0883,
#   'disc_year': 2019,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'TOI-2141 b',
#   'hostname': 'TOI-2141',
#   'pl_letter': 'b',
#   'pl_bmasse': 24.0,
#   'pl_bmassj': 0.075,
#   'pl_rade': 3.05,
#   'pl_radj': 0.278,
#   'pl_orbper': 18.26157,
#   'pl_dens': 4.6,
#   'pl_trandur': 4.9,
#   'pl_ratror': 0.0284,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.94,
#   'st_lum': -0.05,
#   'st_age': 6.4,
#   'st_dens': None,
#   'sy_dist': 77.682,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2525 b',
#   'hostname': 'TOI-2525',
#   'pl_letter': 'b',
#   'pl_bmasse': 26.69759,
#   'pl_bmassj': 0.084,
#   'pl_rade': 8.676,
#   'pl_radj': 0.774,
#   'pl_orbper': 23.2856,
#   'pl_dens': 0.225,
#   'pl_trandur': 4.05,
#   'pl_ratror': 0.1013,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.85,
#   'st_lum': -0.44,
#   'st_age': 3.99,
#   'st_dens': None,
#   'sy_dist': 395.398,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-3785 b',
#   'hostname': 'TOI-3785',
#   'pl_letter': 'b',
#   'pl_bmasse': 14.95,
#   'pl_bmassj': 0.04704,
#   'pl_rade': 5.14,
#   'pl_radj': 0.459,
#   'pl_orbper': 4.6747373,
#   'pl_dens': 0.61,
#   'pl_trandur': 1.7,
#   'pl_ratror': 0.0962,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.52,
#   'st_lum': -1.435,
#   'st_age': 8.0,
#   'st_dens': None,
#   'sy_dist': 79.7634,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-3984 A b',
#   'hostname': 'TOI-3984 A',
#   'pl_letter': 'b',
#   'pl_bmasse': 44.0,
#   'pl_bmassj': 0.14,
#   'pl_rade': 7.9,
#   'pl_radj': 0.71,
#   'pl_orbper': 4.353326,
#   'pl_dens': 0.49,
#   'pl_trandur': 2.01,
#   'pl_ratror': 0.1558,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.49,
#   'st_lum': None,
#   'st_age': 2.9,
#   'st_dens': 6.9,
#   'sy_dist': 108.883,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-124 b',
#   'hostname': 'WASP-124',
#   'pl_letter': 'b',
#   'pl_bmasse': 190.698,
#   'pl_bmassj': 0.6,
#   'pl_rade': 13.899,
#   'pl_radj': 1.24,
#   'pl_orbper': 3.37265,
#   'pl_dens': 0.43,
#   'pl_trandur': 2.5704,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.07,
#   'st_lum': None,
#   'st_age': 2.1,
#   'st_dens': 1.39,
#   'sy_dist': 448.637,
#   'disc_year': 2016,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-25 b',
#   'hostname': 'WASP-25',
#   'pl_letter': 'b',
#   'pl_bmasse': 139.8452,
#   'pl_bmassj': 0.44,
#   'pl_rade': 11.994,
#   'pl_radj': 1.07,
#   'pl_orbper': 3.76483,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.67,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 1.82,
#   'sy_dist': 211.416,
#   'disc_year': 2010,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5293 A b',
#   'hostname': 'TOI-5293 A',
#   'pl_letter': 'b',
#   'pl_bmasse': 170.4,
#   'pl_bmassj': 0.54,
#   'pl_rade': 11.9,
#   'pl_radj': 1.06,
#   'pl_orbper': 2.930289,
#   'pl_dens': 0.56,
#   'pl_trandur': 1.94,
#   'pl_ratror': 0.21,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.54,
#   'st_lum': None,
#   'st_age': 2.9,
#   'st_dens': 5.4,
#   'sy_dist': 162.229,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-107 b',
#   'hostname': 'K2-107',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 15.98,
#   'pl_radj': 1.426,
#   'pl_orbper': 3.313959,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.081,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.3,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 0.457,
#   'sy_dist': 685.2,
#   'disc_year': 2017,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-13 b',
#   'hostname': 'WASP-13',
#   'pl_letter': 'b',
#   'pl_bmasse': 114.4188,
#   'pl_bmassj': 0.36,
#   'pl_rade': 13.675,
#   'pl_radj': 1.22,
#   'pl_orbper': 4.35301,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.72,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 0.4,
#   'sy_dist': 227.537,
#   'disc_year': 2009,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-155 c',
#   'hostname': 'K2-155',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.6,
#   'pl_radj': 0.232,
#   'pl_orbper': 13.85,
#   'pl_dens': None,
#   'pl_trandur': 3.528,
#   'pl_ratror': 0.0321,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.65,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 72.7998,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': '55 Cnc d',
#   'hostname': '55 Cnc',
#   'pl_letter': 'd',
#   'pl_bmasse': 991.6,
#   'pl_bmassj': 3.12,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 5574.2,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 12.5855,
#   'disc_year': 2002,
#   'disc_telescope': '3.0 m C. Donald Shane Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'K2-148 c',
#   'hostname': 'K2-148',
#   'pl_letter': 'c',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 1.73,
#   'pl_radj': 0.154,
#   'pl_orbper': 6.9226,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0251,
#   'sy_snum': 2,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.65,
#   'st_lum': -0.996,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 124.458,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'eps CrB b',
#   'hostname': 'eps CrB',
#   'pl_letter': 'b',
#   'pl_bmasse': 2129.461,
#   'pl_bmassj': 6.7,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 417.9,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.7,
#   'st_lum': None,
#   'st_age': 1.74,
#   'st_dens': None,
#   'sy_dist': 69.8683,
#   'disc_year': 2012,
#   'disc_telescope': '1.8 m Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': "Teegarden's Star b",
#   'hostname': "Teegarden's Star",
#   'pl_letter': 'b',
#   'pl_bmasse': 1.16,
#   'pl_bmassj': 0.00365,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 4.90634,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.1,
#   'st_lum': -3.141,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 3.83078,
#   'disc_year': 2019,
#   'disc_telescope': '3.5 m telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': "Teegarden's Star c",
#   'hostname': "Teegarden's Star",
#   'pl_letter': 'c',
#   'pl_bmasse': 1.05,
#   'pl_bmassj': 0.0033,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 11.416,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.1,
#   'st_lum': -3.141,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 3.83078,
#   'disc_year': 2019,
#   'disc_telescope': '3.5 m telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'TOI-1347 b',
#   'hostname': 'TOI-1347',
#   'pl_letter': 'b',
#   'pl_bmasse': 11.1,
#   'pl_bmassj': 0.03492,
#   'pl_rade': 1.8,
#   'pl_radj': 0.161,
#   'pl_orbper': 0.84742346,
#   'pl_dens': 9.9,
#   'pl_trandur': None,
#   'pl_ratror': 0.02039,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': -0.26,
#   'st_age': 1.4,
#   'st_dens': 2.3,
#   'sy_dist': 147.476,
#   'disc_year': 2024,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-1347 c',
#   'hostname': 'TOI-1347',
#   'pl_letter': 'c',
#   'pl_bmasse': 6.4,
#   'pl_bmassj': 0.02014,
#   'pl_rade': 1.6,
#   'pl_radj': 0.143,
#   'pl_orbper': 4.841962,
#   'pl_dens': 4.1,
#   'pl_trandur': None,
#   'pl_ratror': 0.0179,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': -0.26,
#   'st_age': 1.4,
#   'st_dens': 2.3,
#   'sy_dist': 147.476,
#   'disc_year': 2024,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-1273 b',
#   'hostname': 'TOI-1273',
#   'pl_letter': 'b',
#   'pl_bmasse': 70.55791,
#   'pl_bmassj': 0.222,
#   'pl_rade': 11.097,
#   'pl_radj': 0.99,
#   'pl_orbper': 4.631296,
#   'pl_dens': 0.28,
#   'pl_trandur': None,
#   'pl_ratror': 0.096,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': 0.029,
#   'st_age': 3.1,
#   'st_dens': None,
#   'sy_dist': 177.118,
#   'disc_year': 2024,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'LHS 1140 b',
#   'hostname': 'LHS 1140',
#   'pl_letter': 'b',
#   'pl_bmasse': 5.6,
#   'pl_bmassj': 0.01762,
#   'pl_rade': 1.73,
#   'pl_radj': 0.154,
#   'pl_orbper': 24.73723,
#   'pl_dens': 5.9,
#   'pl_trandur': 2.15,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.18,
#   'st_lum': -2.42,
#   'st_age': 5.0,
#   'st_dens': 25.8,
#   'sy_dist': 14.9861,
#   'disc_year': 2017,
#   'disc_telescope': '0.4 m MEarth Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'LHS 1140 c',
#   'hostname': 'LHS 1140',
#   'pl_letter': 'c',
#   'pl_bmasse': 1.91,
#   'pl_bmassj': 0.00601,
#   'pl_rade': 1.272,
#   'pl_radj': 0.113,
#   'pl_orbper': 3.77794,
#   'pl_dens': 5.1,
#   'pl_trandur': 1.13,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.18,
#   'st_lum': -2.42,
#   'st_age': 5.0,
#   'st_dens': 25.8,
#   'sy_dist': 14.9861,
#   'disc_year': 2018,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5803 b',
#   'hostname': 'TOI-5803',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 3.273,
#   'pl_radj': 0.292,
#   'pl_orbper': 5.38305,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0393,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.87,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 84.0126,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': '55 Cnc b',
#   'hostname': '55 Cnc',
#   'pl_letter': 'b',
#   'pl_bmasse': 255.4,
#   'pl_bmassj': 0.8036,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 14.6516,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 12.5855,
#   'disc_year': 1996,
#   'disc_telescope': '3.0 m C. Donald Shane Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': '55 Cnc c',
#   'hostname': '55 Cnc',
#   'pl_letter': 'c',
#   'pl_bmasse': 51.2,
#   'pl_bmassj': 0.1611,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 44.3989,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 5,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 12.5855,
#   'disc_year': 2004,
#   'disc_telescope': '9.2 m Hobby-Eberly Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'WASP-58 b',
#   'hostname': 'WASP-58',
#   'pl_letter': 'b',
#   'pl_bmasse': 308.2951,
#   'pl_bmassj': 0.97,
#   'pl_rade': 16.029,
#   'pl_radj': 1.43,
#   'pl_orbper': 5.01718,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.06,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 0.83,
#   'sy_dist': 290.404,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-4791 b',
#   'hostname': 'TOI-4791',
#   'pl_letter': 'b',
#   'pl_bmasse': 734.18362,
#   'pl_bmassj': 2.31,
#   'pl_rade': 12.442,
#   'pl_radj': 1.11,
#   'pl_orbper': 4.28088,
#   'pl_dens': 2.09,
#   'pl_trandur': 3.334,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.24,
#   'st_lum': 0.38,
#   'st_age': 3.3,
#   'st_dens': 0.624,
#   'sy_dist': 328.802,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5174 b',
# ...
#   'pl_orbper': 0.658524,
#   'pl_dens': None,
#   'pl_trandur': 0.33336,
#   'pl_ratror': 0.043,
#   'sy_snum': 2,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 0.69,
#   'st_lum': -0.823,
#   'st_age': None,
#   'st_dens': 2.79,
#   'sy_dist': 77.5586,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 2685 b',
#   'hostname': 'HD 2685',
#   'pl_letter': 'b',
#   'pl_bmasse': 371.8611,
#   'pl_bmassj': 1.17,
#   'pl_rade': 16.141,
#   'pl_radj': 1.44,
#   'pl_orbper': 4.12688,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.09467,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.43,
#   'st_lum': 0.668,
#   'st_age': 1.31,
#   'st_dens': None,
#   'sy_dist': 196.852,
#   'disc_year': 2019,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'K2-237 b',
#   'hostname': 'K2-237',
#   'pl_letter': 'b',
#   'pl_bmasse': 433.20012,
#   'pl_bmassj': 1.363,
#   'pl_rade': 16.197,
#   'pl_radj': 1.445,
#   'pl_orbper': 2.18053539,
#   'pl_dens': 0.562,
#   'pl_trandur': 2.9278,
#   'pl_ratror': 0.1177,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.26,
#   'st_lum': 0.371,
#   'st_age': 1.02,
#   'st_dens': 0.888,
#   'sy_dist': 314.995,
#   'disc_year': 2018,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HAT-P-39 b',
#   'hostname': 'HAT-P-39',
#   'pl_letter': 'b',
#   'pl_bmasse': 190.372,
#   'pl_bmassj': 0.599,
#   'pl_rade': 17.609,
#   'pl_radj': 1.571,
#   'pl_orbper': 3.54387,
#   'pl_dens': 0.19,
#   'pl_trandur': 4.188,
#   'pl_ratror': 0.0993,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.4,
#   'st_lum': 0.607,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 697.004,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5542 b',
#   'hostname': 'TOI-5542',
#   'pl_letter': 'b',
#   'pl_bmasse': 419.5335,
#   'pl_bmassj': 1.32,
#   'pl_rade': 11.31,
#   'pl_radj': 1.009,
#   'pl_orbper': 75.12375,
#   'pl_dens': 1.6,
#   'pl_trandur': None,
#   'pl_ratror': 0.098,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.89,
#   'st_lum': 1.057,
#   'st_age': 10.8,
#   'st_dens': 1.03,
#   'sy_dist': 348.849,
#   'disc_year': 2022,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-421 c',
#   'hostname': 'TOI-421',
#   'pl_letter': 'c',
#   'pl_bmasse': 16.42,
#   'pl_bmassj': 0.05166,
#   'pl_rade': 5.09,
#   'pl_radj': 0.454,
#   'pl_orbper': 16.06819,
#   'pl_dens': 0.685,
#   'pl_trandur': 2.71,
#   'pl_ratror': 0.0542,
#   'sy_snum': 2,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.85,
#   'st_lum': None,
#   'st_age': 9.4,
#   'st_dens': 2.72,
#   'sy_dist': 74.7969,
#   'disc_year': 2020,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-451 d',
#   'hostname': 'TOI-451',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 4.07,
#   'pl_radj': 0.363,
#   'pl_orbper': 16.364988,
#   'pl_dens': None,
#   'pl_trandur': 4.0968,
#   'pl_ratror': 0.04246,
#   'sy_snum': 2,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.95,
#   'st_lum': -0.189,
#   'st_age': 0.12,
#   'st_dens': 1.824,
#   'sy_dist': 123.739,
#   'disc_year': 2020,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'NGTS-2 b',
#   'hostname': 'NGTS-2',
#   'pl_letter': 'b',
#   'pl_bmasse': 235.1942,
#   'pl_bmassj': 0.74,
#   'pl_rade': 17.878,
#   'pl_radj': 1.595,
#   'pl_orbper': 4.511164,
#   'pl_dens': 0.226,
#   'pl_trandur': 4.651,
#   'pl_ratror': 0.09619,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.64,
#   'st_lum': None,
#   'st_age': 2.17,
#   'st_dens': 0.477,
#   'sy_dist': 356.391,
#   'disc_year': 2018,
#   'disc_telescope': '20 cm Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'GJ 1132 c',
#   'hostname': 'GJ 1132',
#   'pl_letter': 'c',
#   'pl_bmasse': 2.64,
#   'pl_bmassj': 0.00831,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 8.929,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.18,
#   'st_lum': -2.359,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 12.613,
#   'disc_year': 2018,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'TOI-700 b',
#   'hostname': 'TOI-700',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 0.914,
#   'pl_radj': 0.082,
#   'pl_orbper': 9.977219,
#   'pl_dens': None,
#   'pl_trandur': 2.17,
#   'pl_ratror': 0.01993,
#   'sy_snum': 1,
#   'sy_pnum': 4,
#   'sy_mnum': 0,
#   'st_mass': 0.41,
#   'st_lum': -1.64,
#   'st_age': None,
#   'st_dens': 7.86,
#   'sy_dist': 31.1265,
#   'disc_year': 2020,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-28 b',
#   'hostname': 'WASP-28',
#   'pl_letter': 'b',
#   'pl_bmasse': 282.54945,
#   'pl_bmassj': 0.889,
#   'pl_rade': 13.664,
#   'pl_radj': 1.219,
#   'pl_orbper': 3.40883495,
#   'pl_dens': 0.65116,
#   'pl_trandur': 3.2388,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.99,
#   'st_lum': None,
#   'st_age': 5.5,
#   'st_dens': 1.1018,
#   'sy_dist': 348.494,
#   'disc_year': 2014,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-49 b',
#   'hostname': 'WASP-49',
#   'pl_letter': 'b',
#   'pl_bmasse': 117.5971,
#   'pl_bmassj': 0.37,
#   'pl_rade': 12.442,
#   'pl_radj': 1.11,
#   'pl_orbper': 2.78174,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.92,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 1.43,
#   'sy_dist': 194.553,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HAT-P-51 b',
#   'hostname': 'HAT-P-51',
#   'pl_letter': 'b',
#   'pl_bmasse': 97.57332,
#   'pl_bmassj': 0.307,
#   'pl_rade': 13.507,
#   'pl_radj': 1.205,
#   'pl_orbper': 4.21802091,
#   'pl_dens': 0.218,
#   'pl_trandur': None,
#   'pl_ratror': 0.1253,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.96,
#   'st_lum': -0.102,
#   'st_age': 8.1,
#   'st_dens': 1.38,
#   'sy_dist': 440.089,
#   'disc_year': 2015,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-904 b',
#   'hostname': 'TOI-904',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 2.426,
#   'pl_radj': 0.216,
#   'pl_orbper': 10.8772,
#   'pl_dens': None,
#   'pl_trandur': 3.65,
#   'pl_ratror': 0.039,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.56,
#   'st_lum': -1.292,
#   'st_age': 1.5,
#   'st_dens': 5.36,
#   'sy_dist': 46.0891,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HATS-13 b',
#   'hostname': 'HATS-13',
#   'pl_letter': 'b',
#   'pl_bmasse': 172.58169,
#   'pl_bmassj': 0.543,
#   'pl_rade': 13.585,
#   'pl_radj': 1.212,
#   'pl_orbper': 3.0440499,
#   'pl_dens': 0.377,
#   'pl_trandur': 2.63472,
#   'pl_ratror': 0.1402,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.96,
#   'st_lum': None,
#   'st_age': 2.5,
#   'st_dens': 1.93,
#   'sy_dist': 421.855,
#   'disc_year': 2015,
#   'disc_telescope': '0.18 m Takahashi Epsilon Astrograph',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-5238 b',
#   'hostname': 'TOI-5238',
#   'pl_letter': 'b',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 5.22,
#   'pl_radj': 0.466,
#   'pl_orbper': 4.872171,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.0,
#   'st_lum': -0.023,
#   'st_age': None,
#   'st_dens': 1.3175,
#   'sy_dist': 290.646,
#   'disc_year': 2022,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-84 c',
#   'hostname': 'WASP-84',
#   'pl_letter': 'c',
#   'pl_bmasse': 15.2,
#   'pl_bmassj': 0.048,
#   'pl_rade': 1.95,
#   'pl_radj': 0.174,
#   'pl_orbper': 1.4468849,
#   'pl_dens': 11.2,
#   'pl_trandur': 1.111,
#   'pl_ratror': 0.0233,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.85,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 100.588,
#   'disc_year': 2023,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HAT-P-38 b',
#   'hostname': 'HAT-P-38',
#   'pl_letter': 'b',
#   'pl_bmasse': 84.857,
#   'pl_bmassj': 0.267,
#   'pl_rade': 9.247,
#   'pl_radj': 0.825,
#   'pl_orbper': 4.640382,
#   'pl_dens': 0.59,
#   'pl_trandur': 3.0408,
#   'pl_ratror': 0.0918,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.89,
#   'st_lum': -0.208,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 255.206,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-144 b',
#   'hostname': 'WASP-144',
#   'pl_letter': 'b',
#   'pl_bmasse': 139.8452,
#   'pl_bmassj': 0.44,
#   'pl_rade': 9.528,
#   'pl_radj': 0.85,
#   'pl_orbper': 2.2783152,
#   'pl_dens': 0.95,
#   'pl_trandur': 1.9536,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.81,
#   'st_lum': None,
#   'st_age': 8.71,
#   'st_dens': 2.17,
#   'sy_dist': 355.513,
#   'disc_year': 2018,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-125 c',
#   'hostname': 'TOI-125',
#   'pl_letter': 'c',
#   'pl_bmasse': 6.63,
#   'pl_bmassj': 0.02086,
#   'pl_rade': 2.759,
#   'pl_radj': 0.246,
#   'pl_orbper': 9.15059,
#   'pl_dens': 1.73,
#   'pl_trandur': 2.9544,
#   'pl_ratror': 0.02985,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.86,
#   'st_lum': -0.285,
#   'st_age': 6.8,
#   'st_dens': 1.99,
#   'sy_dist': 111.059,
#   'disc_year': 2019,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-75 b',
#   'hostname': 'WASP-75',
#   'pl_letter': 'b',
#   'pl_bmasse': 340.06,
#   'pl_bmassj': 1.07,
#   'pl_rade': 14.235,
#   'pl_radj': 1.27,
#   'pl_orbper': 2.484193,
#   'pl_dens': 0.69,
#   'pl_trandur': 1.9728,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.14,
#   'st_lum': None,
#   'st_age': 3.5,
#   'st_dens': 0.79,
#   'sy_dist': 294.001,
#   'disc_year': 2013,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-17 b',
#   'hostname': 'WASP-17',
#   'pl_letter': 'b',
#   'pl_bmasse': 247.9074,
#   'pl_bmassj': 0.78,
#   'pl_rade': 20.961,
#   'pl_radj': 1.87,
#   'pl_orbper': 3.73543,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.28,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 0.98,
#   'sy_dist': 405.908,
#   'disc_year': 2009,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-120 b',
#   'hostname': 'WASP-120',
#   'pl_letter': 'b',
#   'pl_bmasse': 1541.4755,
#   'pl_bmassj': 4.85,
#   'pl_rade': 16.511,
#   'pl_radj': 1.473,
#   'pl_orbper': 3.6112706,
#   'pl_dens': 2.0,
#   'pl_trandur': 3.5592,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.39,
#   'st_lum': None,
#   'st_age': 2.6,
#   'st_dens': 0.299,
#   'sy_dist': 381.174,
#   'disc_year': 2016,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'KELT-6 c',
#   'hostname': 'KELT-6',
#   'pl_letter': 'c',
#   'pl_bmasse': 1179.1493,
#   'pl_bmassj': 3.71,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 1276.0,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 1.13,
#   'st_lum': None,
#   'st_age': 4.9,
#   'st_dens': 0.44,
#   'sy_dist': 240.726,
#   'disc_year': 2015,
#   'disc_telescope': 'Multiple Telescopes',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'TOI-905 b',
#   'hostname': 'TOI-905',
#   'pl_letter': 'b',
#   'pl_bmasse': 211.99261,
#   'pl_bmassj': 0.667,
#   'pl_rade': 13.126,
#   'pl_radj': 1.171,
#   'pl_orbper': 3.739494,
#   'pl_dens': 0.515,
#   'pl_trandur': 2.028,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.97,
#   'st_lum': -0.137,
#   'st_age': 3.4,
#   'st_dens': 1.76,
#   'sy_dist': 158.649,
#   'disc_year': 2020,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-67 b',
#   'hostname': 'WASP-67',
#   'pl_letter': 'b',
#   'pl_bmasse': 136.6669,
#   'pl_bmassj': 0.43,
#   'pl_rade': 12.89,
#   'pl_radj': 1.15,
#   'pl_orbper': 4.61442,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.91,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': 1.88,
#   'sy_dist': 189.469,
#   'disc_year': 2012,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'WASP-7 b',
#   'hostname': 'WASP-7',
#   'pl_letter': 'b',
#   'pl_bmasse': 305.1168,
#   'pl_bmassj': 0.96,
#   'pl_rade': 14.908,
#   'pl_radj': 1.33,
#   'pl_orbper': 4.9546416,
#   'pl_dens': 0.55,
#   'pl_trandur': None,
#   'pl_ratror': 0.0956,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.28,
#   'st_lum': None,
#   'st_age': 2.4,
#   'st_dens': 0.611,
#   'sy_dist': 162.303,
#   'disc_year': 2008,
#   'disc_telescope': 'Canon 200mm f/1.8L',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-1749 d',
#   'hostname': 'TOI-1749',
#   'pl_letter': 'd',
#   'pl_bmasse': 15.0,
#   'pl_bmassj': 0.0472,
#   'pl_rade': 2.52,
#   'pl_radj': 0.225,
#   'pl_orbper': 9.0497,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': 0.0421,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 0.58,
#   'st_lum': None,
#   'st_age': 0.8,
#   'st_dens': 5.02,
#   'sy_dist': 99.5561,
#   'disc_year': 2021,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'TOI-2158 b',
#   'hostname': 'TOI-2158',
#   'pl_letter': 'b',
#   'pl_bmasse': 260.61929,
#   'pl_bmassj': 0.82,
#   'pl_rade': 10.761,
#   'pl_radj': 0.96,
#   'pl_orbper': 8.60077,
#   'pl_dens': 1.14,
#   'pl_trandur': 3.77,
#   'pl_ratror': 0.07,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.12,
#   'st_lum': None,
#   'st_age': 8.0,
#   'st_dens': 0.56,
#   'sy_dist': 198.473,
#   'disc_year': 2022,
#   'disc_telescope': '0.1 m TESS Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 103774 b',
#   'hostname': 'HD 103774',
#   'pl_letter': 'b',
#   'pl_bmasse': 116.0,
#   'pl_bmassj': 0.367,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 5.8881,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.33,
#   'st_lum': 0.544,
#   'st_age': 1.05,
#   'st_dens': None,
#   'sy_dist': 56.4089,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'HD 109271 c',
#   'hostname': 'HD 109271',
#   'pl_letter': 'c',
#   'pl_bmasse': 24.154,
#   'pl_bmassj': 0.076,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 30.93,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 1.05,
#   'st_lum': 0.301,
#   'st_age': 7.3,
#   'st_dens': None,
#   'sy_dist': 55.8716,
#   'disc_year': 2013,
#   'disc_telescope': '3.6 m ESO Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  {'pl_name': 'Kepler-450 d',
#   'hostname': 'Kepler-450',
#   'pl_letter': 'd',
#   'pl_bmasse': None,
#   'pl_bmassj': None,
#   'pl_rade': 0.837,
#   'pl_radj': 0.075,
#   'pl_orbper': 7.51464,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 3,
#   'sy_mnum': 0,
#   'st_mass': 1.19,
#   'st_lum': 0.554,
#   'st_age': None,
#   'st_dens': 0.3792,
#   'sy_dist': 455.982,
#   'disc_year': 2015,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit'},
#  {'pl_name': 'HD 10647 b',
#   'hostname': 'HD 10647',
#   'pl_letter': 'b',
#   'pl_bmasse': 298.75,
#   'pl_bmassj': 0.94,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 989.2,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.11,
#   'st_lum': 0.149,
#   'st_age': 1.4,
#   'st_dens': None,
#   'sy_dist': 17.3357,
#   'disc_year': 2006,
#   'disc_telescope': '10 m Keck I Telescope',
#   'discoverymethod': 'Radial Velocity'},
#  ...]

# %%
df_exo7 = pd.DataFrame.from_records(list7)
df_exo7
# Out:
#             pl_name     hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  \
# 0      OGLE-TR-10 b   OGLE-TR-10         b    197.046       0.62   14.011
# 1      BD-08 2823 c   BD-08 2823         c    104.000       0.33      NaN
# 2         HR 8799 c      HR 8799         c   3000.000      10.00   13.000
# 3       HD 110014 b    HD 110014         b   3524.590      11.09      NaN
# 4         WASP-43 b      WASP-43         b    565.714       1.78   10.424
# ...             ...          ...       ...        ...        ...      ...
# 5673  Kepler-1986 b  Kepler-1986         b        NaN        NaN    1.890
# 5674  Kepler-1980 b  Kepler-1980         b        NaN        NaN    2.210
# 5675  Kepler-1996 c  Kepler-1996         c        NaN        NaN    2.810
# 5676  Kepler-2001 c  Kepler-2001         c        NaN        NaN    1.820
# 5677  Kepler-1985 b  Kepler-1985         b        NaN        NaN    2.270
#
#       pl_radj     pl_orbper  pl_dens  pl_trandur  ...  sy_pnum  sy_mnum  \
# 0        1.25      3.101278    0.400         NaN  ...        1        0
# 1         NaN    237.600000      NaN         NaN  ...        2        0
# 2        1.20  69000.000000      NaN         NaN  ...        4        0
# 3         NaN    835.477000      NaN         NaN  ...        1        0
# 4        0.93      0.813475    2.939      1.1592  ...        1        0
# ...       ...           ...      ...         ...  ...      ...      ...
# 5673      NaN     19.548967      NaN      1.7800  ...        1        0
# 5674      NaN     33.025718      NaN      6.0320  ...        1        0
# 5675      NaN     92.729725      NaN      6.8300  ...        2        0
# 5676      NaN     14.092583      NaN      4.1536  ...        2        0
# 5677      NaN      3.420647      NaN      1.7670  ...        1        0
#
#       st_mass  st_lum  st_age  st_dens    sy_dist  disc_year  \
# 0        1.14   0.188     NaN      NaN  1344.9700       2004
# 1        0.74     NaN    4.50      NaN    41.3342       2009
# 2        1.50   0.692    0.06      NaN    41.2441       2008
# 3        2.17     NaN    0.95      NaN   100.7580       2009
# 4        0.58     NaN     NaN      NaN    86.7467       2011
# ...       ...     ...     ...      ...        ...        ...
# 5673     0.78     NaN     NaN   6.2798   912.0850       2023
# 5674     1.05     NaN     NaN   1.3454  1709.4000       2023
# 5675     0.75     NaN     NaN   0.4944   440.5610       2023
# 5676     0.86     NaN     NaN   0.9739   776.5500       2023
# 5677     0.88     NaN     NaN   0.4717        NaN       2023
#
#                          disc_telescope  discoverymethod
# 0     1.3 m Warsaw University Telescope          Transit
# 1                   3.6 m ESO Telescope  Radial Velocity
# 2         8.19 m Gemini North Telescope          Imaging
# 3                   Multiple Telescopes  Radial Velocity
# 4                    Canon 200mm f/1.8L          Transit
# ...                                 ...              ...
# 5673            0.95 m Kepler Telescope          Transit
# 5674            0.95 m Kepler Telescope          Transit
# 5675            0.95 m Kepler Telescope          Transit
# 5676            0.95 m Kepler Telescope          Transit
# 5677            0.95 m Kepler Telescope          Transit
#
# [5678 rows x 22 columns]

# %%
df_exo7.columns
# Out:
# Index(['pl_name', 'hostname', 'pl_letter', 'pl_bmasse', 'pl_bmassj', 'pl_rade',
#        'pl_radj', 'pl_orbper', 'pl_dens', 'pl_trandur', 'pl_ratror', 'sy_snum',
#        'sy_pnum', 'sy_mnum', 'st_mass', 'st_lum', 'st_age', 'st_dens',
#        'sy_dist', 'disc_year', 'disc_telescope', 'discoverymethod'],
#       dtype='object')

# %%
df_exo7['sy_dist']#en parsecs=3.26 annee lumiere
# Out:
# 0       1344.9700
# 1         41.3342
# 2         41.2441
# 3        100.7580
# 4         86.7467
#           ...
# 5673     912.0850
# 5674    1709.4000
# 5675     440.5610
# 5676     776.5500
# 5677          NaN
# Name: sy_dist, Length: 5678, dtype: float64

# %%
df_exo7[df_exo7['sy_dist'] < 10.00]
# Out:
#           pl_name   hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  \
# 19     GJ 667 C b   GJ 667 C         b        NaN        NaN      NaN
# 20     GJ 667 C c   GJ 667 C         c      3.800    0.01200      NaN
# 21     GJ 667 C e   GJ 667 C         e      2.700    0.00800      NaN
# 22     GJ 667 C f   GJ 667 C         f      2.700    0.00800      NaN
# 23     GJ 667 C g   GJ 667 C         g      4.600    0.01400      NaN
# ...           ...        ...       ...        ...        ...      ...
# 3959  Wolf 1061 b  Wolf 1061         b      1.910    0.00601      NaN
# 3981     GJ 251 b     GJ 251         b      4.000    0.01259      NaN
# 3991     GJ 273 b     GJ 273         b      2.890    0.00909      NaN
# 4005  HD 180617 b  HD 180617         b     12.214    0.03843      NaN
# 4132     GJ 514 b     GJ 514         b      5.200    0.01636      NaN
#
#       pl_radj  pl_orbper  pl_dens  pl_trandur  ...  sy_pnum  sy_mnum  st_mass  \
# 19        NaN     7.2030      NaN         NaN  ...        5        0      NaN
# 20        NaN    28.1400      NaN         NaN  ...        5        0     0.33
# 21        NaN    62.2400      NaN         NaN  ...        5        0     0.33
# 22        NaN    39.0260      NaN         NaN  ...        5        0     0.33
# 23        NaN   256.2000      NaN         NaN  ...        5        0     0.33
# ...       ...        ...      ...         ...  ...      ...      ...      ...
# 3959      NaN     4.8869      NaN         NaN  ...        3        0     0.29
# 3981      NaN    14.2380      NaN         NaN  ...        1        0     0.36
# 3991      NaN    18.6498      NaN         NaN  ...        2        0     0.29
# 4005      NaN   105.9110      NaN         NaN  ...        1        0     0.48
# 4132      NaN   140.4300      NaN         NaN  ...        1        0     0.51
#
#       st_lum  st_age  st_dens   sy_dist  disc_year         disc_telescope  \
# 19       NaN     NaN      NaN  7.243960       2012    3.6 m ESO Telescope
# 20    -1.863     2.0      NaN  7.243960       2013    3.6 m ESO Telescope
# 21    -1.863     2.0      NaN  7.243960       2013    3.6 m ESO Telescope
# 22    -1.863     2.0      NaN  7.243960       2013    3.6 m ESO Telescope
# 23    -1.863     2.0      NaN  7.243960       2013    3.6 m ESO Telescope
# ...      ...     ...      ...       ...        ...                    ...
# 3959  -1.991     NaN      NaN  4.305920       2015    3.6 m ESO Telescope
# 3981  -1.772     NaN      NaN  5.580570       2020  10 m Keck I Telescope
# 3991  -2.056     NaN      NaN  5.921535       2017    3.6 m ESO Telescope
# 4005  -1.490     NaN      NaN  5.910590       2018        3.5 m telescope
# 4132  -1.367     0.8      NaN  7.617780       2022    Multiple Telescopes
#
#       discoverymethod
# 19    Radial Velocity
# 20    Radial Velocity
# 21    Radial Velocity
# 22    Radial Velocity
# 23    Radial Velocity
# ...               ...
# 3959  Radial Velocity
# 3981  Radial Velocity
# 3991  Radial Velocity
# 4005  Radial Velocity
# 4132  Radial Velocity
#
# [106 rows x 22 columns]

# %%
nb_df_exo7_sy_dist_inf_10=df_exo7[df_exo7['sy_dist'] < 10.00]['pl_name'].count()
nb_df_exo7_sy_dist_inf_20=df_exo7[(df_exo7['sy_dist'] >= 10.00)&(df_exo7['sy_dist'] < 20.00)]['pl_name'].count()
nb_df_exo7_sy_dist_inf_30=df_exo7[(df_exo7['sy_dist'] >= 20.00)&(df_exo7['sy_dist'] < 30.00)]['pl_name'].count()

print(nb_df_exo7_sy_dist_inf_10)
print(nb_df_exo7_sy_dist_inf_20)
print(nb_df_exo7_sy_dist_inf_30)
# Out:
# 106
# 167
# 185
