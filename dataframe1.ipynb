# %%
import pandas as pd
import numpy as np

# %%
dfcom = pd.DataFrame({
'CONTRAT':['CT1','CT2','CT3','CT4','CT5','CT6','CT7','CT8','CT9','CT10','CT11','CT12','CT13','CT14','CT15',
'CT16','CT17','CT18','CT19','CT20','CT21','CT22','CT23','CT24','CT25','CT26','CT27','CT28','CT29','CT30',
'CT31','CT32','CT33','CT34','CT35','CT36','CT37','CT38','CT39','CT40','CT41','CT42','CT43','CT44','CT45',
'CT46','CT47','CT48','CT49','CT50','CT51','CT52','CT53','CT54','CT55','CT56','CT57','CT58','CT59','CT60']
    , 
'GEST':['GE1','GE1','GE1','GE2','GE2','GE3','GE3','GE1','GE2','GE4','GE1','GE1','GE1','GE2','GE2',
'GE3','GE3','GE1','GE2','GE4','GE1','GE1','GE1','GE2','GE2','GE3','GE3','GE1','GE2','GE3',
'GE1','GE1','GE1','GE2','GE2','GE3','GE3','GE1','GE2','GE4','GE1','GE1','GE1','GE2','GE2',
'GE3','GE3','GE1','GE2','GE4','GE1','GE1','GE1','GE2','GE2','GE3','GE3','GE1','GE2','GE3']
    ,
'CC':['CC2','CC1','CC1','CC2','CC2','CC3','CC3','CC1','CC2','CC4','CC1','CC1','CC1','CC2','CC2',
'CC3','CC3','CC1','CC2','CC4','CC1','CC1','CC1','CC2','CC2','CC3','CC3','CC1','CC2','CC1',
'CC1','CC1','CC1','CC2','CC2','CC3','CC3','CC1','CC2','CC4','CC1','CC1','CC1','CC2','CC2',
'CC3','CC3','CC1','CC2','CC3','CC1','CC1','CC1','CC2','CC2','CC3','CC3','CC1','CC2','CC3']
    ,
'PLACEUR':['PL2','PL1','PL1','PL2','PL2','PL3','PL3','PL1','PL2','PL4','PL1','PL1','PL1','PL2','PL2',
'PL3','PL3','PL1','PL2','PL4','PL1','PL1','PL1','PL2','PL2','PL3','PL3','PL1','PL2','PL4',
'PL1','PL1','PL1','PL2','PL2','PL3','PL3','PL1','PL2','PL4','PL1','PL1','PL1','PL2','PL2',
'PL3','PL3','PL1','PL2','PL1','PL1','PL1','PL1','PL2','PL2','PL3','PL3','PL1','PL2','PL1']
                     });

# %%
dfcom
# Out:
#    CONTRAT GEST   CC PLACEUR
# 0      CT1  GE1  CC2     PL2
# 1      CT2  GE1  CC1     PL1
# 2      CT3  GE1  CC1     PL1
# 3      CT4  GE2  CC2     PL2
# 4      CT5  GE2  CC2     PL2
# 5      CT6  GE3  CC3     PL3
# 6      CT7  GE3  CC3     PL3
# 7      CT8  GE1  CC1     PL1
# 8      CT9  GE2  CC2     PL2
# 9     CT10  GE4  CC4     PL4
# 10    CT11  GE1  CC1     PL1
# 11    CT12  GE1  CC1     PL1
# 12    CT13  GE1  CC1     PL1
# 13    CT14  GE2  CC2     PL2
# 14    CT15  GE2  CC2     PL2
# 15    CT16  GE3  CC3     PL3
# 16    CT17  GE3  CC3     PL3
# 17    CT18  GE1  CC1     PL1
# 18    CT19  GE2  CC2     PL2
# 19    CT20  GE4  CC4     PL4
# 20    CT21  GE1  CC1     PL1
# 21    CT22  GE1  CC1     PL1
# 22    CT23  GE1  CC1     PL1
# 23    CT24  GE2  CC2     PL2
# 24    CT25  GE2  CC2     PL2
# 25    CT26  GE3  CC3     PL3
# 26    CT27  GE3  CC3     PL3
# 27    CT28  GE1  CC1     PL1
# 28    CT29  GE2  CC2     PL2
# 29    CT30  GE3  CC1     PL4
# 30    CT31  GE1  CC1     PL1
# ...

# %%
dfcom1=dfcom.loc[(dfcom["GEST"]=="GE4")|(dfcom["CC"]=="CC4")|(dfcom["PLACEUR"]=="PL4"),
          ['CONTRAT', 'GEST',  'CC', 'PLACEUR']];dfcom1
# Out:
#    CONTRAT GEST   CC PLACEUR
# 9     CT10  GE4  CC4     PL4
# 19    CT20  GE4  CC4     PL4
# 29    CT30  GE3  CC1     PL4
# 39    CT40  GE4  CC4     PL4
# 49    CT50  GE4  CC3     PL1

# %%
dfcom1.columns
# Out:
# Index(['CONTRAT', 'GEST', 'CC', 'PLACEUR'], dtype='object')
